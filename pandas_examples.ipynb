# %%
# source: https://www.kaggle.com/ludobenistant/hr-analytics
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline  
df = pd.read_csv("HR_comma_sep.csv")
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# ...

# %%
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
print("The mean satification level was", df["satisfaction_level"].mean())
print("The median satification level was", df["satisfaction_level"].median())
print("The standard deviation of the satification level was", df["satisfaction_level"].std())
print("The variance of the satification level was", df["satisfaction_level"].var())
print("The skew of the satification level was", df["satisfaction_level"].skew())
print("The kurtosis of the satification level was", df["satisfaction_level"].kurt())
# Out:
# The mean satification level was 0.612833522235
# The median satification level was 0.64
# The standard deviation of the satification level was 0.248630651061
# The variance of the satification level was 0.0618172006471
# The skew of the satification level was -0.476360341284
# The kurtosis of the satification level was -0.670858622057

# %%
df["satisfaction_level"].plot.hist()
plt.show()

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df, alpha=0.2, figsize=(12, 12), diagonal='kde')
plt.show()

# %%
from pandas.plotting import andrews_curves

andrews_curves(df, "salary")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-61419cd3d8d9> in <module>()
#       1 from pandas.plotting import andrews_curves
#       2
# ----> 3 andrews_curves(df, "salary")
#       4 plt.show()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#      89                 else:
#      90                     kwargs[new_arg_name] = new_arg_value
# ---> 91             return func(*args, **kwargs)
#      92         return wrapper
#      93     return _deprecate_kwarg
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/plotting/_misc.py in andrews_curves(frame, class_column, ax, samples, color, colormap, **kwds)
#     309         row = df.iloc[i].values
#     310         f = function(row)
# --> 311         y = f(t)
# ...

# %%
from pandas.plotting import andrews_curves
import numpy as np
iris = pd.read_csv("https://raw.githubusercontent.com/pandas-dev/pandas/master/pandas/tests/data/iris.csv")
andrews_curves(iris, 'Name')

# %%
cols = df.columns.tolist()
cols.remove("sales")
no_sales = df[cols]
andrews_curves(no_sales, 'salary')
